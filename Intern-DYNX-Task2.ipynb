# %% [markdown]
# <a href="https://colab.research.google.com/github/SGopika1/Intern-DYNX-Task2/blob/main/Intern-DYNX-Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: import upload utility
from google.colab import files

# Step 2: run this cell and choose the file from your computer
uploaded = files.upload()
import pandas as pd

data = {
    'HoursStudied': [5.94, 7.44, 6.42, 5.9, 4.81, 6.81, 4.94, 9.03, 9.67, 4.45, 8.13, 5.76, 6.11, 9.33, 1.64, 1.78, 1.18, 8.49, 8, 8.83, 9.81, 8.19, 5.15, 8.02, 2.06, 6.76, 2.29, 9.5, 5.7, 4.73, 3.38, 7.97, 5.11, 6.12, 1.17, 6.56, 6.51, 6.55, 9.49, 7.14, 4.24, 4.93, 7.28, 1.54, 7, 7.04, 2.89, 2.16, 3.84, 4.27],
    'ExamScore': [21.17, 46.95, 29.55, 27.31, 17.79, 37.94, 16.63, 44.09, 43.87, 24.18, 38.1, 22.9, 30.41, 48.79, 8.53, 10.41, 2.73, 40.64, 36.64, 42.35, 44.98, 32.32, 26.64, 38.09, 2.15, 36.11, 6.91, 47.76, 32.15, 24.29, 22.6, 33.68, 27.56, 27.18, 1.5, 29.91, 30.99, 33.03, 41.62, 40.2, 23.53, 16.97, 43.84, 17.18, 40.89, 34.3, 9.1, 16.07, 17.18, 27.46]
}

df = pd.DataFrame(data)
print(df.head())
# Out:
#      <input type="file" id="files-8a2ca4e9-8a5e-4e2e-a135-baa8c7f30567" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a2ca4e9-8a5e-4e2e-a135-baa8c7f30567">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
